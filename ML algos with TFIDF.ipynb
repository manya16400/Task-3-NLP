# %%
import pandas as pd

train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.columns
# Out:
# Index(['Unnamed: 0', 'product_name', 'product_category_tree', 'description',
#        'brand', 'product_specifications', 'Label', 'Label_1st_category',
#        'des_preprocess', 'all_features_preprocess'],
#       dtype='object')

# %% [markdown]
# # Main category as label

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, auc
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import classification_report
from sklearn.metrics import average_precision_score
from sklearn.metrics import f1_score
import warnings
warnings.filterwarnings('ignore')

# %%
categories = list(set(train['Label_1st_category']))

# %%
# Naive Bayes Classifer
from sklearn.naive_bayes import MultinomialNB
def nb_classifier(X_train, X_test, y_train, y_test):
  
    nb = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('clf', MultinomialNB()),
                ])
    nb.fit(X_train, y_train)

    y_pred = nb.predict(X_test)
    
    return accuracy_score(y_pred, y_test), classification_report(y_test, y_pred,target_names=categories)

# %%
# Linear SVM

from sklearn.linear_model import SGDClassifier
def linear_svm(X_train, X_test, y_train, y_test):
  
    sgd = Pipeline([('vect', CountVectorizer()),
                  ('tfidf', TfidfTransformer()),
                  ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=42, max_iter=5, tol=None)),
                 ])
    sgd.fit(X_train, y_train)

    y_pred = sgd.predict(X_test)
 
    return accuracy_score(y_pred, y_test), classification_report(y_test, y_pred,target_names=categories)

# %%
# Logistic Regrassion

from sklearn.linear_model import LogisticRegression
def logisticreg(X_train, X_test, y_train, y_test):

    logreg = Pipeline([('vect', CountVectorizer()),
                  ('tfidf', TfidfTransformer()),
                  ('clf', LogisticRegression(n_jobs=1, C=1e5,max_iter=500)),
                 ])
    logreg.fit(X_train, y_train)

    y_pred = logreg.predict(X_test)

    return accuracy_score(y_pred, y_test), classification_report(y_test, y_pred,target_names=categories)

# %%
# Random Forest 

from sklearn.ensemble import RandomForestClassifier
def randomforest(X_train, X_test, y_train, y_test):
    
    ranfor = Pipeline([('vect', CountVectorizer()),
                  ('tfidf', TfidfTransformer()),
                  ('clf', RandomForestClassifier(n_estimators = 1000, random_state = 42)),
                 ])
    ranfor.fit(X_train, y_train)

    y_pred = ranfor.predict(X_test)

    return accuracy_score(y_pred, y_test), classification_report(y_test, y_pred,target_names=categories)

# %%
# MLP CLassifier

def mlpclassifier(X_train, X_test, y_train, y_test):
  
    from sklearn.neural_network import MLPClassifier
    
    mlp = Pipeline([('vect', CountVectorizer()),
                  ('tfidf', TfidfTransformer()),
                  ('clf', MLPClassifier(hidden_layer_sizes=(30,30,30))),
                 ])
    mlp.fit(X_train, y_train)

    y_pred = mlp.predict(X_test)

    return accuracy_score(y_pred, y_test), classification_report(y_test, y_pred,target_names=categories)

# %%
from sklearn.model_selection import train_test_split

print("\033[1mUsing Description as feature\033[0m")
X_train, X_test, y_train, y_test = train_test_split(list(train['des_preprocess']),list(train['Label_1st_category']) , test_size=0.2, random_state = 42) 

print("NB Classifier: ")
acc,mat=nb_classifier(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)
print(mat)
print('-'*75)

print("Linear SVM: ")
acc,mat=linear_svm(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)
print(mat)
print('-'*79)

print("Logistic Reg: ")
acc,mat=logisticreg(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)
print(mat)
print('-'*75)

print("Random Forest: ")
acc,mat=randomforest(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)
print(mat)
print('-'*75)

print("MLP Classifier: ")
acc,mat=mlpclassifier(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)
print(mat)
print('-'*75)


print("\033[1m Using product_name, description, brand, product_specifications as feature \033[0m")
X_train, X_test, y_train, y_test = train_test_split(list(train['all_features_preprocess']),list(train['Label_1st_category']) , test_size=0.2, random_state = 42) 

print("NB Classifier: ")
acc,mat=nb_classifier(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)
print(mat)
print('-'*75)

print("Linear SVM: ")
acc,mat=linear_svm(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)
print(mat)
print('-'*75)

print("Logistic Reg: ")
acc,mat=logisticreg(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)
print(mat)
print('-'*75)

print("Random Forest: ")
acc,mat=randomforest(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)
print(mat)
print('-'*75)

print("MLP Classifier: ")
acc,mat=mlpclassifier(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)
print(mat)
# Out:
# Using Description as feature
# NB Classifier:
# Accuracy:  0.8661485319516408
#                             precision    recall  f1-score   support
#
#   Beauty and Personal Care       0.96      0.96      0.96       187
#            Home Furnishing       0.97      0.38      0.54        77
#           Tools & Hardware       0.67      0.04      0.08        46
#                   Footwear       1.00      0.58      0.74       132
#     Toys & School Supplies       0.86      1.00      0.92      1114
#                  Baby Care       1.00      0.72      0.84       108
#                  Computers       1.00      0.91      0.95       197
#      Bags, Wallets & Belts       1.00      0.64      0.78        22
# Home Decor & Festive Needs       0.91      0.82      0.86       182
#      Mobiles & Accessories       0.95      0.84      0.89       113
#                    Watches       0.00      0.00      0.00         3
#          Pens & Stationery       0.73      1.00      0.84       635
#           Sports & Fitness       0.97      0.67      0.79        97
#                 Automotive       0.95      0.97      0.96       222
#           Home Improvement       1.00      0.22      0.35        65
#           Kitchen & Dining       0.00      0.00      0.00        27
#                   Clothing       1.00      0.77      0.87        84
#                  Furniture       0.83      0.08      0.15        61
#                  Jewellery       1.00      0.96      0.98       102
#
#                   accuracy                           0.87      3474
#                  macro avg       0.83      0.61      0.66      3474
#               weighted avg       0.88      0.87      0.84      3474
#
# ---------------------------------------------------------------------------
# Linear SVM:
# Accuracy:  0.9499136442141624
#                             precision    recall  f1-score   support
#
#   Beauty and Personal Care       0.95      0.97      0.96       187
#            Home Furnishing       0.94      0.57      0.71        77
#           Tools & Hardware       0.87      0.72      0.79        46
#                   Footwear       0.95      0.93      0.94       132
#     Toys & School Supplies       0.97      1.00      0.98      1114
#                  Baby Care       0.92      0.91      0.91       108
#                  Computers       0.93      0.97      0.95       197
#      Bags, Wallets & Belts       0.91      0.95      0.93        22
# Home Decor & Festive Needs       0.90      0.91      0.90       182
#      Mobiles & Accessories       0.91      0.99      0.95       113
#                    Watches       1.00      0.33      0.50         3
#          Pens & Stationery       0.98      1.00      0.99       635
#           Sports & Fitness       0.94      0.92      0.93        97
#                 Automotive       0.97      0.98      0.97       222
#           Home Improvement       0.97      0.52      0.68        65
#           Kitchen & Dining       0.89      0.63      0.74        27
#                   Clothing       0.95      0.88      0.91        84
#                  Furniture       0.68      0.82      0.74        61
#                  Jewellery       0.99      1.00      1.00       102
#
#                   accuracy                           0.95      3474
#                  macro avg       0.93      0.84      0.87      3474
#               weighted avg       0.95      0.95      0.95      3474
#
# -------------------------------------------------------------------------------
# Logistic Reg:
# Accuracy:  0.982153137593552
#                             precision    recall  f1-score   support
#
#   Beauty and Personal Care       1.00      0.98      0.99       187
#            Home Furnishing       0.95      0.90      0.92        77
#           Tools & Hardware       0.88      0.96      0.92        46
#                   Footwear       0.99      0.98      0.98       132
#     Toys & School Supplies       1.00      1.00      1.00      1114
#                  Baby Care       0.96      0.97      0.97       108
#                  Computers       0.99      1.00      1.00       197
#      Bags, Wallets & Belts       1.00      0.95      0.98        22
# Home Decor & Festive Needs       0.96      0.96      0.96       182
#      Mobiles & Accessories       0.97      1.00      0.99       113
#                    Watches       1.00      0.67      0.80         3
#          Pens & Stationery       1.00      1.00      1.00       635
#           Sports & Fitness       0.95      0.98      0.96        97
#                 Automotive       0.98      0.98      0.98       222
#           Home Improvement       0.87      0.89      0.88        65
#           Kitchen & Dining       0.93      0.96      0.95        27
#                   Clothing       0.99      0.95      0.97        84
#                  Furniture       0.84      0.84      0.84        61
#                  Jewellery       1.00      1.00      1.00       102
#
#                   accuracy                           0.98      3474
#                  macro avg       0.96      0.95      0.95      3474
#               weighted avg       0.98      0.98      0.98      3474
#
# ---------------------------------------------------------------------------
# Random Forest:
# Accuracy:  0.966321243523316
#                             precision    recall  f1-score   support
#
#   Beauty and Personal Care       0.99      0.98      0.99       187
#            Home Furnishing       0.98      0.71      0.83        77
#           Tools & Hardware       0.92      0.78      0.85        46
#                   Footwear       0.99      0.93      0.96       132
#     Toys & School Supplies       0.97      1.00      0.99      1114
#                  Baby Care       0.88      0.95      0.92       108
#                  Computers       0.98      0.97      0.98       197
#      Bags, Wallets & Belts       0.96      1.00      0.98        22
# Home Decor & Festive Needs       0.90      0.96      0.93       182
#      Mobiles & Accessories       0.97      1.00      0.98       113
#                    Watches       1.00      0.67      0.80         3
#          Pens & Stationery       0.99      0.99      0.99       635
#           Sports & Fitness       0.94      0.93      0.93        97
#                 Automotive       0.97      0.99      0.98       222
#           Home Improvement       0.88      0.78      0.83        65
#           Kitchen & Dining       0.96      0.81      0.88        27
#                   Clothing       0.97      0.90      0.94        84
#                  Furniture       0.82      0.80      0.81        61
#                  Jewellery       1.00      1.00      1.00       102
#
#                   accuracy                           0.97      3474
#                  macro avg       0.95      0.90      0.92      3474
#               weighted avg       0.97      0.97      0.97      3474
#
# ---------------------------------------------------------------------------
# MLP Classifier:
# Accuracy:  0.9732297063903281
#                             precision    recall  f1-score   support
#
#   Beauty and Personal Care       1.00      0.96      0.98       187
#            Home Furnishing       0.93      0.90      0.91        77
#           Tools & Hardware       0.84      0.93      0.89        46
#                   Footwear       1.00      0.93      0.96       132
#     Toys & School Supplies       1.00      1.00      1.00      1114
#                  Baby Care       0.93      0.95      0.94       108
#                  Computers       0.98      1.00      0.99       197
#      Bags, Wallets & Belts       1.00      0.91      0.95        22
# Home Decor & Festive Needs       0.94      0.93      0.94       182
#      Mobiles & Accessories       0.97      1.00      0.99       113
#                    Watches       1.00      0.67      0.80         3
#          Pens & Stationery       1.00      1.00      1.00       635
#           Sports & Fitness       0.90      0.95      0.92        97
#                 Automotive       1.00      0.96      0.98       222
#           Home Improvement       0.78      0.82      0.80        65
#           Kitchen & Dining       0.81      0.93      0.86        27
#                   Clothing       0.99      0.95      0.97        84
#                  Furniture       0.75      0.87      0.80        61
#                  Jewellery       1.00      1.00      1.00       102
#
#                   accuracy                           0.97      3474
#                  macro avg       0.94      0.93      0.93      3474
#               weighted avg       0.97      0.97      0.97      3474
#
# ---------------------------------------------------------------------------
#  Using product_name, description, brand, product_specifications as feature
# NB Classifier:
# Accuracy:  0.872769142199194
#                             precision    recall  f1-score   support
#
#   Beauty and Personal Care       0.96      0.94      0.95       187
#            Home Furnishing       0.97      0.42      0.58        77
#           Tools & Hardware       0.00      0.00      0.00        46
#                   Footwear       1.00      0.64      0.78       132
#     Toys & School Supplies       0.79      1.00      0.88      1114
#                  Baby Care       1.00      0.79      0.88       108
#                  Computers       1.00      0.93      0.96       197
#      Bags, Wallets & Belts       0.95      0.82      0.88        22
# Home Decor & Festive Needs       0.97      0.81      0.88       182
#      Mobiles & Accessories       0.96      0.75      0.84       113
#                    Watches       0.00      0.00      0.00         3
#          Pens & Stationery       0.85      1.00      0.92       635
#           Sports & Fitness       1.00      0.64      0.78        97
#                 Automotive       0.95      1.00      0.97       222
#           Home Improvement       1.00      0.26      0.41        65
#           Kitchen & Dining       0.00      0.00      0.00        27
#                   Clothing       1.00      0.74      0.85        84
#                  Furniture       0.68      0.28      0.40        61
#                  Jewellery       1.00      0.94      0.97       102
#
#                   accuracy                           0.87      3474
#                  macro avg       0.79      0.63      0.68      3474
#               weighted avg       0.87      0.87      0.85      3474
#
# ---------------------------------------------------------------------------
# Linear SVM:
# Accuracy:  0.9527921704087507
#                             precision    recall  f1-score   support
#
#   Beauty and Personal Care       0.96      0.97      0.97       187
#            Home Furnishing       0.94      0.62      0.75        77
#           Tools & Hardware       0.88      0.78      0.83        46
#                   Footwear       0.94      0.94      0.94       132
#     Toys & School Supplies       0.97      1.00      0.99      1114
#                  Baby Care       0.88      0.91      0.89       108
#                  Computers       0.94      1.00      0.97       197
#      Bags, Wallets & Belts       0.96      1.00      0.98        22
# Home Decor & Festive Needs       0.94      0.91      0.92       182
#      Mobiles & Accessories       0.90      1.00      0.95       113
#                    Watches       1.00      0.33      0.50         3
#          Pens & Stationery       0.97      1.00      0.99       635
#           Sports & Fitness       0.95      0.87      0.91        97
#                 Automotive       0.97      0.97      0.97       222
#           Home Improvement       0.97      0.51      0.67        65
#           Kitchen & Dining       0.94      0.63      0.76        27
#                   Clothing       0.94      0.88      0.91        84
#                  Furniture       0.68      0.82      0.74        61
#                  Jewellery       0.99      1.00      1.00       102
#
#                   accuracy                           0.95      3474
#                  macro avg       0.93      0.85      0.87      3474
#               weighted avg       0.95      0.95      0.95      3474
#
# ---------------------------------------------------------------------------
# Logistic Reg:
# Accuracy:  0.9815774323546345
#                             precision    recall  f1-score   support
#
#   Beauty and Personal Care       1.00      0.98      0.99       187
#            Home Furnishing       0.93      0.88      0.91        77
#           Tools & Hardware       0.92      0.96      0.94        46
#                   Footwear       0.98      0.98      0.98       132
#     Toys & School Supplies       1.00      1.00      1.00      1114
#                  Baby Care       0.97      0.96      0.97       108
#                  Computers       0.99      1.00      0.99       197
#      Bags, Wallets & Belts       0.96      1.00      0.98        22
# Home Decor & Festive Needs       0.95      0.96      0.95       182
#      Mobiles & Accessories       0.97      1.00      0.99       113
#                    Watches       1.00      0.67      0.80         3
#          Pens & Stationery       1.00      1.00      1.00       635
#           Sports & Fitness       0.95      0.96      0.95        97
#                 Automotive       0.98      0.99      0.99       222
#           Home Improvement       0.84      0.88      0.86        65
#           Kitchen & Dining       0.96      0.96      0.96        27
#                   Clothing       0.99      0.96      0.98        84
#                  Furniture       0.84      0.80      0.82        61
#                  Jewellery       1.00      1.00      1.00       102
#
#                   accuracy                           0.98      3474
#                  macro avg       0.96      0.94      0.95      3474
#               weighted avg       0.98      0.98      0.98      3474
#
# ---------------------------------------------------------------------------
# Random Forest:
# Accuracy:  0.9666090961427749
#                             precision    recall  f1-score   support
#
#   Beauty and Personal Care       0.99      0.99      0.99       187
#            Home Furnishing       0.98      0.68      0.80        77
#           Tools & Hardware       0.90      0.76      0.82        46
#                   Footwear       0.99      0.95      0.97       132
#     Toys & School Supplies       0.98      1.00      0.99      1114
#                  Baby Care       0.96      0.92      0.94       108
#                  Computers       0.92      0.98      0.95       197
#      Bags, Wallets & Belts       0.96      1.00      0.98        22
# Home Decor & Festive Needs       0.90      0.97      0.93       182
#      Mobiles & Accessories       0.95      0.99      0.97       113
#                    Watches       1.00      0.67      0.80         3
#          Pens & Stationery       0.99      1.00      0.99       635
#           Sports & Fitness       0.94      0.93      0.93        97
#                 Automotive       0.96      0.99      0.98       222
#           Home Improvement       0.94      0.71      0.81        65
#           Kitchen & Dining       1.00      0.81      0.90        27
#                   Clothing       0.97      0.92      0.94        84
#                  Furniture       0.82      0.87      0.84        61
#                  Jewellery       1.00      1.00      1.00       102
#
#                   accuracy                           0.97      3474
#                  macro avg       0.96      0.90      0.92      3474
#               weighted avg       0.97      0.97      0.97      3474
#
# ---------------------------------------------------------------------------
# MLP Classifier:
# Accuracy:  0.97524467472654
#                             precision    recall  f1-score   support
#
#   Beauty and Personal Care       0.99      0.97      0.98       187
#            Home Furnishing       0.91      0.90      0.90        77
#           Tools & Hardware       0.91      0.91      0.91        46
#                   Footwear       0.94      0.95      0.94       132
#     Toys & School Supplies       1.00      1.00      1.00      1114
#                  Baby Care       0.97      0.89      0.93       108
#                  Computers       0.99      1.00      1.00       197
#      Bags, Wallets & Belts       0.96      1.00      0.98        22
# Home Decor & Festive Needs       0.97      0.95      0.96       182
#      Mobiles & Accessories       0.96      1.00      0.98       113
#                    Watches       0.67      0.67      0.67         3
#          Pens & Stationery       1.00      1.00      1.00       635
#           Sports & Fitness       0.97      0.92      0.94        97
#                 Automotive       0.97      0.98      0.98       222
#           Home Improvement       0.89      0.89      0.89        65
#           Kitchen & Dining       0.59      0.89      0.71        27
#                   Clothing       0.98      0.95      0.96        84
#                  Furniture       0.86      0.84      0.85        61
#                  Jewellery       1.00      1.00      1.00       102
#
#                   accuracy                           0.98      3474
#                  macro avg       0.92      0.93      0.92      3474
#               weighted avg       0.98      0.98      0.98      3474

# %% [markdown]
# # Label category based on most common categories in the dataset as label

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, auc
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import classification_report
from sklearn.metrics import average_precision_score
from sklearn.metrics import f1_score
import warnings
warnings.filterwarnings('ignore')

# %%
# Naive Bayes Classifer
from sklearn.naive_bayes import MultinomialNB
def nb_classifier(X_train, X_test, y_trai, y_test):
  
    nb = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('clf', MultinomialNB()),
                ])
    nb.fit(X_train, y_train)

    y_pred = nb.predict(X_test)
    
    return accuracy_score(y_pred, y_test)

# %%
# Linear SVM

from sklearn.linear_model import SGDClassifier
def linear_svm(X_train, X_test, y_train, y_test):
  
    sgd = Pipeline([('vect', CountVectorizer()),
                  ('tfidf', TfidfTransformer()),
                  ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=42, max_iter=5, tol=None)),
                 ])
    sgd.fit(X_train, y_train)

    y_pred = sgd.predict(X_test)
 
    return accuracy_score(y_pred, y_test)

# %%
# Logistic Regrassion

from sklearn.linear_model import LogisticRegression
def logisticreg(X_train, X_test, y_train, y_test):

    logreg = Pipeline([('vect', CountVectorizer()),
                  ('tfidf', TfidfTransformer()),
                  ('clf', LogisticRegression(n_jobs=1, C=1e5,max_iter=500)),
                 ])
    logreg.fit(X_train, y_train)

    y_pred = logreg.predict(X_test)
    print(len(set(y_pred)),len(set(y_test)),len(set(y_train)))
    return accuracy_score(y_pred, y_test)

# %%
# Random Forest 

from sklearn.ensemble import RandomForestClassifier
def randomforest(X_train, X_test, y_train, y_test):
    
    ranfor = Pipeline([('vect', CountVectorizer()),
                  ('tfidf', TfidfTransformer()),
                  ('clf', RandomForestClassifier(n_estimators = 1000, random_state = 42)),
                 ])
    ranfor.fit(X_train, y_train)

    y_pred = ranfor.predict(X_test)

    return accuracy_score(y_pred, y_test)

# %%
# MLP CLassifier

def mlpclassifier(X_train, X_test, y_train, y_test):
  
    from sklearn.neural_network import MLPClassifier
    
    
    mlp = Pipeline([('vect', CountVectorizer()),
                  ('tfidf', TfidfTransformer()),
                  ('clf', MLPClassifier(hidden_layer_sizes=(30,30,30))),
                 ])
    mlp.fit(X_train, y_train)

    y_pred = mlp.predict(X_test)

    return accuracy_score(y_pred, y_test)

# %%
from sklearn.model_selection import train_test_split

print("\033[1mUsing Description as feature\033[0m")
X_train, X_test, y_train, y_test = train_test_split(list(train['des_preprocess']),list(train['Label']) , test_size=0.2, random_state = 42) 

print("NB Classifier: ")
acc=nb_classifier(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)


print("Linear SVM: ")
acc=linear_svm(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)


print("Logistic Reg: ")
acc=logisticreg(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)


print("Random Forest: ")
acc=randomforest(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)


print("MLP Classifier: ")
acc=mlpclassifier(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)

print('-'*75)


print("\033[1m Using product_name, description, brand, product_specifications as feature \033[0m")
X_train, X_test, y_train, y_test = train_test_split(list(train['all_features_preprocess']),list(train['Label']) , test_size=0.2, random_state = 42) 

print("NB Classifier: ")
acc=nb_classifier(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)


print("Linear SVM: ")
acc=linear_svm(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)


print("Logistic Reg: ")
acc=logisticreg(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)


print("Random Forest: ")
acc=randomforest(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)


print("MLP Classifier: ")
acc=mlpclassifier(X_train, X_test, y_train, y_test)
print('Accuracy: ',acc)
# Out:
# Using Description as feature
# NB Classifier:
# Accuracy:  0.6776050662061025
# Linear SVM:
# Accuracy:  0.8799654576856649
# Logistic Reg:
# 89 90 95
# Accuracy:  0.947035118019574
# Random Forest:
# Accuracy:  0.9234312032239493
# MLP Classifier:
# Accuracy:  0.8986758779504893
# ---------------------------------------------------------------------------
#  Using product_name, description, brand, product_specifications as feature
# NB Classifier:
# Accuracy:  0.717328727691422
# Linear SVM:
# Accuracy:  0.8831318364997122
# Logistic Reg:
# 88 90 95
# Accuracy:  0.9533678756476683
# Random Forest:
# Accuracy:  0.9214162348877375
# MLP Classifier:
# Accuracy:  0.9159470351180196

# %% [markdown]
# # Testing the best model for Main category on test dataset

# %%
# Logistic Regrassion

from sklearn.linear_model import LogisticRegression
def logisticreg(X_train, X_test, y_train, y_test):

    logreg = Pipeline([('vect', CountVectorizer()),
                  ('tfidf', TfidfTransformer()),
                  ('clf', LogisticRegression(n_jobs=1, C=1e5,max_iter=500)),
                 ])
    logreg.fit(X_train, y_train)

    #y_pred = logreg.predict(X_test)

    return logreg

X_train, X_test, y_train, y_test = train_test_split(list(train['des_preprocess']),list(train['Label_1st_category']) , test_size=0.2, random_state = 42) 
model=logisticreg(X_train, X_test, y_train, y_test)

# %%
label=[]
for i in range(len(test)):
    label.append(test['product_category_tree'][i][1:-2].replace("'","").split(", ")[0])
#test['Label_1st_category'] = label
print(len(label))
# Out:
# 2000

# %%
y_pred = model.predict(test['des_preprocess'])
accuracy_score(y_pred,label)
# Out:
# 0.934

# %% [markdown]
# Test accuracy is 93.4 %
