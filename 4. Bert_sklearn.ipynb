# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/midas/train.csv')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'product_name', 'product_category_tree', 'description',
#        'brand', 'product_specifications', 'Label', 'Label_1st_category',
#        'des_preprocess', 'all_features_preprocess'],
#       dtype='object')

# %% [markdown]
# ### Main category as Label and description as feature

# %%
#splitting dataset

labels=data['Label_1st_category'][:12761]
x=data['des_preprocess'][:12761]
X_train, X_test, y_train, y_test = train_test_split(x,labels, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (10208,)
# (2553,)

# %%
# !git clone -b master https://github.com/charles9n/bert-sklearn
# !cd bert-sklearn; pip install .
import os
os.chdir("bert-sklearn")
print(os.listdir())
# Out:
# Cloning into 'bert-sklearn'...
# remote: Enumerating objects: 259, done.
# remote: Total 259 (delta 0), reused 0 (delta 0), pack-reused 259
# Receiving objects: 100% (259/259), 516.15 KiB | 12.90 MiB/s, done.
# Resolving deltas: 100% (131/131), done.
# Processing /content/bert-sklearn
# ...
#      |████████████████████████████████| 102kB 5.6MB/s
# ...
#      |████████████████████████████████| 7.4MB 12.1MB/s
# ...
#      |████████████████████████████████| 81kB 12.5MB/s
# ...
#   Created wheel for bert-sklearn: filename=bert_sklearn-0.3.1-cp37-none-any.whl size=54235 sha256=ce69cc221a899d9a2d3c8e405a06284876d8b93ef909e71a95488e600e6827de
#   Stored in directory: /root/.cache/pip/wheels/61/95/c6/5790aae8fb377f5ff356dbe58205aab28858595d6bff8197d0
# ...
#   Created wheel for boto3: filename=boto3-1.17.49-py2.py3-none-any.whl size=128780 sha256=e850753933b0e2cf5e1105fbe8b2eeed3e4bb90ac3f36866e3c9bc4f2cc3f08b
#   Stored in directory: /root/.cache/pip/wheels/03/b1/01/9e2fc2b05c6a254c29192a33e40dec0486588261372745ab27
# ...

# %%
import os
import math
import random
import csv
import sys

import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn.metrics import f1_score,accuracy_score
from sklearn.metrics import classification_report
import statistics as stats

from bert_sklearn import BertClassifier
from bert_sklearn import BertRegressor
from bert_sklearn import BertTokenClassifier
from bert_sklearn import load_model
import matplotlib.pyplot as plt
import seaborn as sns
import xml.etree.ElementTree as ET
import nltk
import re

# %%
model = BertClassifier( max_seq_length=64, train_batch_size=16)
model.num_mlp_layers = 4 
model
# Out:
# Building sklearn text classifier...
# BertClassifier(bert_config_json=None, bert_model='bert-base-uncased',
#                bert_vocab=None, do_lower_case=None, epochs=3, eval_batch_size=8,
#                fp16=False, from_tf=False, gradient_accumulation_steps=1,
#                ignore_label=None, label_list=None, learning_rate=2e-05,
#                local_rank=-1, logfile='bert_sklearn.log', loss_scale=0,
#                max_seq_length=64, num_mlp_hiddens=500, num_mlp_layers=4,
#                random_state=42, restore_file=None, train_batch_size=16,
#                use_cuda=True, validation_fraction=0.1, warmup_proportion=0.1)

# %%
scores_BERT = []; 
for seed in [4, 27, 33]:
    model.random_state = seed
    model.fit(X_train, y_train)
    scores_BERT.append(model.score(X_test, y_test))
# Out:
# 100%|██████████| 231508/231508 [00:00<00:00, 884815.34B/s]
# Loading bert-base-uncased model...
# ...
# 100%|██████████| 433/433 [00:00<00:00, 104315.54B/s]
# Using mlp with D=768,H=500,K=19,n=4
# Loading Pytorch checkpoint
#
# train data size: 9188, validation data size: 1020
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...
# /content/bert-sklearn/bert_sklearn/model/pytorch_pretrained/optimization.py:275: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %% [markdown]
# ### Main category as Label and Product_name, description, brand, product_specifications as feature

# %%
#splitting dataset

labels=data['Label_1st_category']
x=data['all_features_preprocess']
X_train, X_test, y_train, y_test = train_test_split(x,labels, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (13894,)
# (3474,)

# %%
# !git clone -b master https://github.com/charles9n/bert-sklearn
# !cd bert-sklearn; pip install .
import os
os.chdir("bert-sklearn")
print(os.listdir())
# Out:
# Cloning into 'bert-sklearn'...
# remote: Enumerating objects: 259, done.
# remote: Total 259 (delta 0), reused 0 (delta 0), pack-reused 259
# Receiving objects: 100% (259/259), 516.15 KiB | 12.00 MiB/s, done.
# Resolving deltas: 100% (131/131), done.
# Processing /content/bert-sklearn/bert-sklearn
# ...
#   Created wheel for bert-sklearn: filename=bert_sklearn-0.3.1-cp37-none-any.whl size=54235 sha256=9dec48ab4ed349bf16219a63c6333d3914e7eb8244a1ee3e04dd6b104f45c543
#   Stored in directory: /root/.cache/pip/wheels/2f/af/73/f678149ed91f19d43eb124b60aa8730ba459c1b4a6e6b91fc8
# Successfully built bert-sklearn
# ...
#   Found existing installation: bert-sklearn 0.3.1
#     Uninstalling bert-sklearn-0.3.1:
#       Successfully uninstalled bert-sklearn-0.3.1
# ...
# ['setup.py', 'README.md', '.git', 'Options.md', 'bert_sklearn', 'other_examples', 'tests', 'glue_examples', 'demo.ipynb', 'demo_tuning_hyperparams.ipynb', 'LICENSE']

# %%
import os
import math
import random
import csv
import sys

import numpy as np
import pandas as pd
from sklearn import metricsl
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
import statistics as stats

from bert_sklearn import BertClassifier
from bert_sklearn import BertRegressor
from bert_sklearn import BertTokenClassifier
from bert_sklearn import load_model
import matplotlib.pyplot as plt
import seaborn as sns
import xml.etree.ElementTree as ET
import nltk
import re

# %%
model = BertClassifier( max_seq_length=64, train_batch_size=16)
model.num_mlp_layers = 4 
model
# Out:
# Building sklearn text classifier...
# BertClassifier(bert_config_json=None, bert_model='bert-base-uncased',
#                bert_vocab=None, do_lower_case=None, epochs=3, eval_batch_size=8,
#                fp16=False, from_tf=False, gradient_accumulation_steps=1,
#                ignore_label=None, label_list=None, learning_rate=2e-05,
#                local_rank=-1, logfile='bert_sklearn.log', loss_scale=0,
#                max_seq_length=64, num_mlp_hiddens=500, num_mlp_layers=4,
#                random_state=42, restore_file=None, train_batch_size=16,
#                use_cuda=True, validation_fraction=0.1, warmup_proportion=0.1)

# %%
scores_BERT = []; 
for seed in [4, 27, 33]:
    model.random_state = seed
    model.fit(X_train, y_train)
    scores_BERT.append(model.score(X_test, y_test))
# Out:
# Loading bert-base-uncased model...
# Using mlp with D=768,H=500,K=19,n=4
# Loading Pytorch checkpoint
#
# train data size: 12505, validation data size: 1389
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...
# Epoch 1, Train loss: 1.0025, Val loss: 0.2134, Val accy: 95.25%
# ...
# Epoch 2, Train loss: 0.2239, Val loss: 0.1371, Val accy: 97.26%
# ...
# Epoch 3, Train loss: 0.1498, Val loss: 0.1261, Val accy: 97.55%
# ...
# Loss: 0.1211, Accuracy: 97.21%
# Loading bert-base-uncased model...
# Using mlp with D=768,H=500,K=19,n=4
# Loading Pytorch checkpoint
#
# ...

# %% [markdown]
# ###  Category based on most common categories in the dataset as label and description as feature

# %%
#splitting dataset

labels=data['Label']
x=data['des_preprocess']
X_train, X_test, y_train, y_test = train_test_split(x,labels, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (13894,)
# (3474,)

# %%
# !git clone -b master https://github.com/charles9n/bert-sklearn
# !cd bert-sklearn; pip install .
import os
os.chdir("bert-sklearn")
print(os.listdir())
# Out:
# Cloning into 'bert-sklearn'...
# remote: Enumerating objects: 259, done.
# remote: Total 259 (delta 0), reused 0 (delta 0), pack-reused 259
# Receiving objects: 100% (259/259), 516.15 KiB | 20.65 MiB/s, done.
# Resolving deltas: 100% (131/131), done.
# Processing /content/bert-sklearn
# ...
#      |████████████████████████████████| 102kB 9.3MB/s
# ...
#      |████████████████████████████████| 7.4MB 40.5MB/s
# ...
#      |████████████████████████████████| 81kB 11.5MB/s
# ...
#   Created wheel for bert-sklearn: filename=bert_sklearn-0.3.1-cp37-none-any.whl size=54235 sha256=627d5aa30ebcd784b03bb267e79816c96604b9394cdd9e15515b33c73656377f
#   Stored in directory: /root/.cache/pip/wheels/61/95/c6/5790aae8fb377f5ff356dbe58205aab28858595d6bff8197d0
# ...
#   Created wheel for boto3: filename=boto3-1.17.49-py2.py3-none-any.whl size=128780 sha256=e09a2b42011ebf439ebddfd628e7efeee6725ad282123d4a5213d3f2ab86f5de
#   Stored in directory: /root/.cache/pip/wheels/03/b1/01/9e2fc2b05c6a254c29192a33e40dec0486588261372745ab27
# ...

# %%
import os
import math
import random
import csv
import sys

import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn.metrics import f1_score,accuracy_score
from sklearn.metrics import classification_report
import statistics as stats

from bert_sklearn import BertClassifier
from bert_sklearn import BertRegressor
from bert_sklearn import BertTokenClassifier
from bert_sklearn import load_model
import matplotlib.pyplot as plt
import seaborn as sns
import xml.etree.ElementTree as ET
import nltk
import re

# %%
model = BertClassifier( max_seq_length=64, train_batch_size=16)
model.num_mlp_layers = 4 
model
# Out:
# Building sklearn text classifier...
# BertClassifier(bert_config_json=None, bert_model='bert-base-uncased',
#                bert_vocab=None, do_lower_case=None, epochs=3, eval_batch_size=8,
#                fp16=False, from_tf=False, gradient_accumulation_steps=1,
#                ignore_label=None, label_list=None, learning_rate=2e-05,
#                local_rank=-1, logfile='bert_sklearn.log', loss_scale=0,
#                max_seq_length=64, num_mlp_hiddens=500, num_mlp_layers=4,
#                random_state=42, restore_file=None, train_batch_size=16,
#                use_cuda=True, validation_fraction=0.1, warmup_proportion=0.1)

# %%
scores_BERT = []; 
for seed in [4, 27, 33]:
    model.random_state = seed
    model.fit(X_train, y_train)
    scores_BERT.append(model.score(X_test, y_test))
# Out:
# ...
#   1%|          | 5314560/440473133 [00:00<00:08, 53140329.43B/s]
# Loading bert-base-uncased model...
# ...
# 100%|██████████| 433/433 [00:00<00:00, 94197.80B/s]
# Using mlp with D=768,H=500,K=95,n=4
# Loading Pytorch checkpoint
#
# train data size: 12505, validation data size: 1389
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...
# /content/bert-sklearn/bert_sklearn/model/pytorch_pretrained/optimization.py:275: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# ...

# %% [markdown]
# ###  Category based on most common categories in the dataset as label and Product_name, description, brand, product_specifications as feature

# %%
#splitting dataset

labels=data['Label']
x=data['all_features_preprocess']
X_train, X_test, y_train, y_test = train_test_split(x,labels, test_size=0.2, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (13894,)
# (3474,)

# %%
# !git clone -b master https://github.com/charles9n/bert-sklearn
# !cd bert-sklearn; pip install .
import os
os.chdir("bert-sklearn")
print(os.listdir())
# Out:
# Cloning into 'bert-sklearn'...
# remote: Enumerating objects: 259, done.
# remote: Total 259 (delta 0), reused 0 (delta 0), pack-reused 259
# Receiving objects: 100% (259/259), 516.15 KiB | 19.85 MiB/s, done.
# Resolving deltas: 100% (131/131), done.
# Processing /content/bert-sklearn/bert-sklearn
# ...
#   Created wheel for bert-sklearn: filename=bert_sklearn-0.3.1-cp37-none-any.whl size=54235 sha256=c9c01e91a9d16497fd9139caa120dfe4abe9d3ca987c5b807f1f1e90176f2497
#   Stored in directory: /root/.cache/pip/wheels/2f/af/73/f678149ed91f19d43eb124b60aa8730ba459c1b4a6e6b91fc8
# Successfully built bert-sklearn
# ...
#   Found existing installation: bert-sklearn 0.3.1
#     Uninstalling bert-sklearn-0.3.1:
#       Successfully uninstalled bert-sklearn-0.3.1
# ...
# ['setup.py', 'README.md', '.git', 'Options.md', 'bert_sklearn', 'other_examples', 'tests', 'glue_examples', 'demo.ipynb', 'demo_tuning_hyperparams.ipynb', 'LICENSE']

# %%
import os
import math
import random
import csv
import sys

import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn.metrics import f1_score,accuracy_score
from sklearn.metrics import classification_report
import statistics as stats

from bert_sklearn import BertClassifier
from bert_sklearn import BertRegressor
from bert_sklearn import BertTokenClassifier
from bert_sklearn import load_model
import matplotlib.pyplot as plt
import seaborn as sns
import xml.etree.ElementTree as ET
import nltk
import re

# %%
model = BertClassifier( max_seq_length=64, train_batch_size=16)
model.num_mlp_layers = 4 
model
# Out:
# Building sklearn text classifier...
# BertClassifier(bert_config_json=None, bert_model='bert-base-uncased',
#                bert_vocab=None, do_lower_case=None, epochs=3, eval_batch_size=8,
#                fp16=False, from_tf=False, gradient_accumulation_steps=1,
#                ignore_label=None, label_list=None, learning_rate=2e-05,
#                local_rank=-1, logfile='bert_sklearn.log', loss_scale=0,
#                max_seq_length=64, num_mlp_hiddens=500, num_mlp_layers=4,
#                random_state=42, restore_file=None, train_batch_size=16,
#                use_cuda=True, validation_fraction=0.1, warmup_proportion=0.1)

# %%
scores_BERT = []; 
for seed in [4, 27, 33]:
    model.random_state = seed
    model.fit(X_train, y_train)
    scores_BERT.append(model.score(X_test, y_test))
# Out:
# Loading bert-base-uncased model...
# Using mlp with D=768,H=500,K=95,n=4
# Loading Pytorch checkpoint
#
# train data size: 12505, validation data size: 1389
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...
# Epoch 1, Train loss: 3.0512, Val loss: 1.7103, Val accy: 65.73%
# ...
# Epoch 2, Train loss: 1.6290, Val loss: 1.0737, Val accy: 82.87%
# ...
# Epoch 3, Train loss: 1.2521, Val loss: 0.9040, Val accy: 85.82%
# ...
# Loss: 0.8945, Accuracy: 85.66%
# Loading bert-base-uncased model...
# Using mlp with D=768,H=500,K=95,n=4
# Loading Pytorch checkpoint
#
# ...
